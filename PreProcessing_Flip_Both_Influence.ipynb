# %%
from FaroPreFlipBoth import PreProcFlip, draw
# Out:
# Seed is 24

# %%
model = PreProcFlip('adult','race',max_iter=700,k=10,credit_lim=1)
res=model.fit_transform()
# Out:
# Iter: 1, Train: (0.8455, 0.0103, 0.0945), Test: (0.8377, 0.0094, 0.0907)
# Iter: 2, Train: (0.8459, 0.0118, 0.0945), Test: (0.8379, 0.0108, 0.0914)
# Iter: 3, Train: (0.8459, 0.0125, 0.0955), Test: (0.8378, 0.0116, 0.0910)
# Iter: 4, Train: (0.8460, 0.0141, 0.0955), Test: (0.8384, 0.0130, 0.0928)
# Iter: 5, Train: (0.8459, 0.0151, 0.0954), Test: (0.8384, 0.0142, 0.0917)
# Iter: 6, Train: (0.8459, 0.0160, 0.0948), Test: (0.8385, 0.0150, 0.0906)
# Iter: 7, Train: (0.8458, 0.0174, 0.0946), Test: (0.8387, 0.0165, 0.0914)
# Iter: 8, Train: (0.8459, 0.0187, 0.0943), Test: (0.8389, 0.0175, 0.0914)
# Iter: 9, Train: (0.8459, 0.0204, 0.0939), Test: (0.8389, 0.0198, 0.0910)
# Iter: 10, Train: (0.8458, 0.0221, 0.0942), Test: (0.8384, 0.0213, 0.0914)
# Iter: 11, Train: (0.8458, 0.0244, 0.0943), Test: (0.8381, 0.0237, 0.0913)
# Iter: 12, Train: (0.8456, 0.0258, 0.0944), Test: (0.8381, 0.0256, 0.0914)
# Iter: 13, Train: (0.8456, 0.0269, 0.0944), Test: (0.8381, 0.0262, 0.0912)
# ...

# %%
draw(res)

# %%
model = PreProcFlip('adult','sex',max_iter=700,k=10,credit_lim=1)
res=model.fit_transform()
# Out:
# Iter: 1, Train: (0.8462, 0.0146, 0.1816), Test: (0.8379, 0.0134, 0.1825)
# Iter: 2, Train: (0.8458, 0.0155, 0.1823), Test: (0.8382, 0.0144, 0.1822)
# Iter: 3, Train: (0.8460, 0.0161, 0.1821), Test: (0.8379, 0.0149, 0.1830)
# Iter: 4, Train: (0.8460, 0.0166, 0.1825), Test: (0.8386, 0.0155, 0.1824)
# Iter: 5, Train: (0.8461, 0.0168, 0.1824), Test: (0.8386, 0.0162, 0.1826)
# Iter: 6, Train: (0.8463, 0.0177, 0.1826), Test: (0.8387, 0.0171, 0.1828)
# Iter: 7, Train: (0.8462, 0.0184, 0.1832), Test: (0.8387, 0.0181, 0.1830)
# Iter: 8, Train: (0.8460, 0.0192, 0.1835), Test: (0.8387, 0.0185, 0.1829)
# Iter: 9, Train: (0.8460, 0.0201, 0.1836), Test: (0.8388, 0.0195, 0.1827)
# Iter: 10, Train: (0.8459, 0.0211, 0.1837), Test: (0.8387, 0.0200, 0.1832)
# Iter: 11, Train: (0.8458, 0.0217, 0.1838), Test: (0.8384, 0.0205, 0.1827)
# Iter: 12, Train: (0.8458, 0.0222, 0.1839), Test: (0.8383, 0.0209, 0.1824)
# Iter: 13, Train: (0.8459, 0.0229, 0.1836), Test: (0.8382, 0.0217, 0.1822)
# ...

# %%
draw(res)
