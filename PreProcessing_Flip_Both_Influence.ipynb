# %%
# %matplotlib notebook

# %%
from PreProcess import PreProcFlip, draw
# Out:
# Traceback (most recent call last):
#
#   File "/Users/haipei/.pyenv/versions/anaconda3-2020.11/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-2-5c86b235fbc3>", line 1, in <module>
#     from PreProcess import PreProcFlip, draw
#
#   File "/Volumes/移动硬盘/fairness-and-robustness/PreProcess.py", line 307
#     model = PreProcFlip("adult", "race", k=10, max_iter=500, seed=None, dR=0.4, dF=0.4)
#         ^
# IndentationError: expected an indented block

# %%
model = PreProcFlip("compas", "race", k=0.0015, max_iter=1000, seed=24, dR=0.4, dF=0.03)
res=model.fit_transform()
# Out:
# Flipping 0.1500% (21) records every epoch
# Iter: 1, Train: (0.7351, 0.1667, 0.1567), Test: (0.7152, 0.1607, 0.1674), Mode: Robustness
# Iter: 2, Train: (0.7373, 0.1405, 0.1612), Test: (0.7130, 0.1368, 0.1660), Mode: Robustness
# Iter: 3, Train: (0.7377, 0.1578, 0.1597), Test: (0.7138, 0.1555, 0.1649), Mode: Robustness
# Iter: 4, Train: (0.7385, 0.1569, 0.1548), Test: (0.7158, 0.1557, 0.1591), Mode: Robustness
# Iter: 5, Train: (0.7388, 0.1226, 0.1626), Test: (0.7120, 0.1213, 0.1630), Mode: Robustness
# Iter: 6, Train: (0.7398, 0.1339, 0.1596), Test: (0.7117, 0.1357, 0.1661), Mode: Robustness
# Iter: 7, Train: (0.7402, 0.1406, 0.1538), Test: (0.7080, 0.1363, 0.1516), Mode: Robustness
# Iter: 8, Train: (0.7400, 0.1476, 0.1527), Test: (0.7087, 0.1468, 0.1527), Mode: Robustness
# Iter: 9, Train: (0.7403, 0.1251, 0.1617), Test: (0.7105, 0.1223, 0.1660), Mode: Robustness
# Iter: 10, Train: (0.7407, 0.1589, 0.1572), Test: (0.7107, 0.1555, 0.1585), Mode: Robustness
# ...

# %%
draw(res)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-50d582d74a7b> in <module>
# ----> 1 draw(res)
#
# NameError: name 'res' is not defined

# %%
model = PreProcFlip("compas", "race", k=10, max_iter=500, seed=24, wR=5.0, wF=0.5)
res=model.fit_transform()
# Out:
# 14000
# Flipping 0.0714% (10) records every epoch
# Iter: 1, Train: (0.7366, 0.1339, 0.1607), Test: (0.7137, 0.1323, 0.1666)
# Iter: 2, Train: (0.7381, 0.1196, 0.1597), Test: (0.7128, 0.1157, 0.1636)
# Iter: 3, Train: (0.7390, 0.1179, 0.1583), Test: (0.7148, 0.1183, 0.1601)
# Iter: 4, Train: (0.7399, 0.1086, 0.1591), Test: (0.7118, 0.1057, 0.1617)
# Iter: 5, Train: (0.7401, 0.1080, 0.1568), Test: (0.7137, 0.1085, 0.1524)
# Iter: 6, Train: (0.7401, 0.1008, 0.1563), Test: (0.7140, 0.0983, 0.1564)
# Iter: 7, Train: (0.7409, 0.0876, 0.1594), Test: (0.7108, 0.0862, 0.1648)
# Iter: 8, Train: (0.7407, 0.0854, 0.1629), Test: (0.7112, 0.0832, 0.1656)
# Iter: 9, Train: (0.7411, 0.0966, 0.1570), Test: (0.7095, 0.0935, 0.1494)
# Iter: 10, Train: (0.7424, 0.0889, 0.1589), Test: (0.7107, 0.0872, 0.1617)
# Iter: 11, Train: (0.7426, 0.0816, 0.1580), Test: (0.7112, 0.0803, 0.1616)
# Iter: 12, Train: (0.7425, 0.0894, 0.1553), Test: (0.7120, 0.0890, 0.1538)
# ...

# %%
draw(res)
