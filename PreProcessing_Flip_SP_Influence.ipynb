# %%
from FaroPreFlip import PreProcFlip, draw

# %%
model = PreProcFlip('adult','race')
res = model.fit_transform()
# Out:
# Iter: 1, Train: (0.8497, 0.0952), Test: (0.8430, 0.0861)
# Iter: 2, Train: (0.8505, 0.0949), Test: (0.8456, 0.0857)
# Iter: 3, Train: (0.8507, 0.0940), Test: (0.8460, 0.0854)
# Iter: 4, Train: (0.8509, 0.0936), Test: (0.8461, 0.0835)
# Iter: 5, Train: (0.8515, 0.0942), Test: (0.8459, 0.0829)
# Iter: 6, Train: (0.8521, 0.0939), Test: (0.8458, 0.0831)
# Iter: 7, Train: (0.8522, 0.0928), Test: (0.8456, 0.0821)
# Iter: 8, Train: (0.8524, 0.0924), Test: (0.8454, 0.0818)
# Iter: 9, Train: (0.8528, 0.0925), Test: (0.8453, 0.0822)
# Iter: 10, Train: (0.8532, 0.0923), Test: (0.8451, 0.0819)
# Iter: 11, Train: (0.8535, 0.0919), Test: (0.8451, 0.0827)
# Iter: 12, Train: (0.8538, 0.0905), Test: (0.8452, 0.0845)
# Iter: 13, Train: (0.8537, 0.0915), Test: (0.8451, 0.0822)
# Iter: 14, Train: (0.8542, 0.0902), Test: (0.8453, 0.0826)
# Iter: 15, Train: (0.8548, 0.0911), Test: (0.8451, 0.0819)
# Iter: 16, Train: (0.8553, 0.0914), Test: (0.8453, 0.0809)
# ...

# %%
draw(res)

# %%
model = PreProcFlip('adult','sex')
res = model.fit_transform()
# Out:
# Iter: 1, Train: (0.8486, 0.1806), Test: (0.8425, 0.1822)
# Iter: 2, Train: (0.8496, 0.1801), Test: (0.8453, 0.1829)
# Iter: 3, Train: (0.8504, 0.1803), Test: (0.8457, 0.1815)
# Iter: 4, Train: (0.8507, 0.1801), Test: (0.8458, 0.1807)
# Iter: 5, Train: (0.8510, 0.1800), Test: (0.8457, 0.1809)
# Iter: 6, Train: (0.8515, 0.1802), Test: (0.8456, 0.1809)
# Iter: 7, Train: (0.8516, 0.1800), Test: (0.8452, 0.1815)
# Iter: 8, Train: (0.8519, 0.1798), Test: (0.8451, 0.1818)
# Iter: 9, Train: (0.8521, 0.1800), Test: (0.8452, 0.1821)
# Iter: 10, Train: (0.8524, 0.1796), Test: (0.8456, 0.1820)
# Iter: 11, Train: (0.8527, 0.1790), Test: (0.8454, 0.1822)
# Iter: 12, Train: (0.8530, 0.1799), Test: (0.8453, 0.1819)
# Iter: 13, Train: (0.8532, 0.1797), Test: (0.8451, 0.1808)
# Iter: 14, Train: (0.8537, 0.1786), Test: (0.8451, 0.1813)
# Iter: 15, Train: (0.8539, 0.1793), Test: (0.8451, 0.1821)
# Iter: 16, Train: (0.8542, 0.1793), Test: (0.8449, 0.1820)
# ...

# %%
draw(res)

# %%
model = PreProcFlip('compas','race')
res = model.fit_transform()
# Out:
# Iter: 1, Train: (0.7209, 0.1541), Test: (0.7202, 0.1686)
# Iter: 2, Train: (0.7217, 0.1542), Test: (0.7200, 0.1683)
# Iter: 3, Train: (0.7225, 0.1539), Test: (0.7198, 0.1690)
# Iter: 4, Train: (0.7234, 0.1540), Test: (0.7198, 0.1690)
# Iter: 5, Train: (0.7239, 0.1553), Test: (0.7203, 0.1695)
# Iter: 6, Train: (0.7249, 0.1540), Test: (0.7198, 0.1690)
# Iter: 7, Train: (0.7254, 0.1553), Test: (0.7202, 0.1698)
# Iter: 8, Train: (0.7263, 0.1551), Test: (0.7205, 0.1704)
# Iter: 9, Train: (0.7270, 0.1551), Test: (0.7205, 0.1704)
# Iter: 10, Train: (0.7280, 0.1537), Test: (0.7198, 0.1696)
# Iter: 11, Train: (0.7291, 0.1537), Test: (0.7195, 0.1698)
# Iter: 12, Train: (0.7294, 0.1538), Test: (0.7191, 0.1685)
# Iter: 13, Train: (0.7301, 0.1538), Test: (0.7191, 0.1685)
# Iter: 14, Train: (0.7307, 0.1530), Test: (0.7189, 0.1692)
# Iter: 15, Train: (0.7314, 0.1530), Test: (0.7189, 0.1692)
# Iter: 16, Train: (0.7320, 0.1532), Test: (0.7197, 0.1693)
# ...

# %%
draw(res)

# %%
model = PreProcFlip('compas','sex')
res = model.fit_transform()
# Out:
# Iter: 1, Train: (0.7217, 0.0335), Test: (0.7183, 0.0264)
# Iter: 2, Train: (0.7225, 0.0334), Test: (0.7182, 0.0262)
# Iter: 3, Train: (0.7232, 0.0345), Test: (0.7180, 0.0261)
# Iter: 4, Train: (0.7237, 0.0350), Test: (0.7179, 0.0265)
# Iter: 5, Train: (0.7242, 0.0344), Test: (0.7177, 0.0261)
# Iter: 6, Train: (0.7251, 0.0344), Test: (0.7177, 0.0261)
# Iter: 7, Train: (0.7257, 0.0340), Test: (0.7177, 0.0261)
# Iter: 8, Train: (0.7266, 0.0346), Test: (0.7180, 0.0263)
# Iter: 9, Train: (0.7270, 0.0322), Test: (0.7176, 0.0247)
# Iter: 10, Train: (0.7284, 0.0347), Test: (0.7182, 0.0260)
# Iter: 11, Train: (0.7293, 0.0343), Test: (0.7183, 0.0265)
# Iter: 12, Train: (0.7301, 0.0339), Test: (0.7180, 0.0269)
# Iter: 13, Train: (0.7304, 0.0312), Test: (0.7188, 0.0322)
# Iter: 14, Train: (0.7310, 0.0331), Test: (0.7183, 0.0247)
# Iter: 15, Train: (0.7317, 0.0328), Test: (0.7182, 0.0255)
# Iter: 16, Train: (0.7322, 0.0326), Test: (0.7176, 0.0251)
# ...

# %%
draw(res)
