# %% [markdown]
# |Disparity $d$|S.Attr. $s_i$|Promoted|Pred. $\hat{y}_i$|Label. $y_{i}$|Flip.Direction|Flip $y_i$?|
# |-------------|-------------|--------|-----------------|--------------|--------------|-----------|
# |d>0          |$s_i$=0      |Y       |$\hat{y}_i$>0.5  |$y_i$<0.5     |FP->TP        |N          |
# |d>0          |$s_i$=0      |Y       |$\hat{y}_i$>0.5  |$y_i$>0.5     |TP->FP        |Y          |
# |d>0          |$s_i$=1      |N       |$\hat{y}_i$>0.5  |$y_i$<0.5     |FP->TP        |Y          |
# |d>0          |$s_i$=1      |N       |$\hat{y}_i$>0.5  |$y_i$>0.5     |TP->FP        |N          |
# |d<0          |$s_i$=0      |N       |$\hat{y}_i$>0.5  |$y_i$<0.5     |FP->TP        |Y          |
# |d<0          |$s_i$=0      |N       |$\hat{y}_i$>0.5  |$y_i$>0.5     |TP->FP        |N          |
# |d<0          |$s_i$=1      |Y       |$\hat{y}_i$>0.5  |$y_i$<0.5     |FP->TP        |N          |
# |d<0          |$s_i$=1      |Y       |$\hat{y}_i$>0.5  |$y_i$>0.5     |TP->FP        |Y          |
# |d>0          |$s_i$=0      |Y       |$\hat{y}_i$<0.5  |$y_i$<0.5     |TN->FN        |N          |
# |d>0          |$s_i$=0      |Y       |$\hat{y}_i$<0.5  |$y_i$>0.5     |FN->TN        |Y          |
# |d>0          |$s_i$=1      |N       |$\hat{y}_i$<0.5  |$y_i$<0.5     |TN->FN        |Y          |
# |d>0          |$s_i$=1      |N       |$\hat{y}_i$<0.5  |$y_i$>0.5     |FN->TN        |N          |
# |d<0          |$s_i$=0      |N       |$\hat{y}_i$<0.5  |$y_i$<0.5     |FN->TN        |Y          |
# |d<0          |$s_i$=0      |N       |$\hat{y}_i$<0.5  |$y_i$>0.5     |TN->FN        |N          |
# |d<0          |$s_i$=1      |Y       |$\hat{y}_i$<0.5  |$y_i$<0.5     |TN->FN        |N          |
# |d<0          |$s_i$=1      |Y       |$\hat{y}_i$<0.5  |$y_i$>0.5     |FN->TN        |Y          |

# %% [markdown]
# Flip rule: $d (s_i-0.5)(\hat{y}_i-0.5)(y_i-0.5) < 0$

# %%
from FaroPreFlip import flip, draw

# %%
res=flip('adult','race',n_epoch=1000,kind='EO',ascending=True)
# Out:
# 0 Train: (0.8493, 0.0585), Test: (0.8433, 0.0384)
# 1 Train: (0.8494, 0.0582), Test: (0.8434, 0.0352)
# 2 Train: (0.8496, 0.0580), Test: (0.8429, 0.0363)
# 3 Train: (0.8498, 0.0597), Test: (0.8430, 0.0357)
# 4 Train: (0.8501, 0.0595), Test: (0.8427, 0.0374)
# 5 Train: (0.8503, 0.0602), Test: (0.8429, 0.0342)
# 6 Train: (0.8499, 0.0590), Test: (0.8429, 0.0369)
# 7 Train: (0.8502, 0.0619), Test: (0.8429, 0.0351)
# 8 Train: (0.8503, 0.0598), Test: (0.8431, 0.0354)
# 9 Train: (0.8506, 0.0608), Test: (0.8431, 0.0322)
# 10 Train: (0.8507, 0.0613), Test: (0.8430, 0.0334)
# 11 Train: (0.8506, 0.0638), Test: (0.8433, 0.0322)
# 12 Train: (0.8508, 0.0609), Test: (0.8431, 0.0337)
# 13 Train: (0.8509, 0.0593), Test: (0.8429, 0.0354)
# 14 Train: (0.8511, 0.0600), Test: (0.8430, 0.0334)
# 15 Train: (0.8514, 0.0618), Test: (0.8428, 0.0293)
# 16 Train: (0.8517, 0.0627), Test: (0.8432, 0.0337)
# 17 Train: (0.8520, 0.0646), Test: (0.8427, 0.0313)
# 18 Train: (0.8520, 0.0637), Test: (0.8430, 0.0328)
# ...

# %%
draw(res)

# %%
res=flip('adult','race',n_epoch=1000,kind='EO',ascending=False)
# Out:
# 0 Train: (0.8493, 0.0585), Test: (0.8433, 0.0384)
# 1 Train: (0.8472, 0.0638), Test: (0.8406, 0.0450)
# 2 Train: (0.8455, 0.0679), Test: (0.8385, 0.0484)
# 3 Train: (0.8438, 0.0678), Test: (0.8365, 0.0442)
# 4 Train: (0.8420, 0.0661), Test: (0.8349, 0.0413)
# 5 Train: (0.8417, 0.0633), Test: (0.8346, 0.0438)
# 6 Train: (0.8411, 0.0666), Test: (0.8346, 0.0424)
# 7 Train: (0.8397, 0.0671), Test: (0.8330, 0.0563)
# 8 Train: (0.8393, 0.0657), Test: (0.8332, 0.0551)
# 9 Train: (0.8391, 0.0634), Test: (0.8333, 0.0530)
# 10 Train: (0.8386, 0.0607), Test: (0.8327, 0.0594)
# 11 Train: (0.8382, 0.0582), Test: (0.8332, 0.0524)
# 12 Train: (0.8377, 0.0567), Test: (0.8336, 0.0574)
# 13 Train: (0.8368, 0.0602), Test: (0.8327, 0.0573)
# 14 Train: (0.8362, 0.0590), Test: (0.8332, 0.0596)
# 15 Train: (0.8359, 0.0564), Test: (0.8331, 0.0608)
# 16 Train: (0.8352, 0.0516), Test: (0.8331, 0.0608)
# 17 Train: (0.8349, 0.0519), Test: (0.8332, 0.0657)
# 18 Train: (0.8336, 0.0495), Test: (0.8327, 0.0639)
# ...

# %%
draw(res)

# %%
res=flip('adult','sex',n_epoch=1000,kind='EO',ascending=True)
# Out:
# 0 Train: (0.8485, 0.1012), Test: (0.8430, 0.0876)
# 1 Train: (0.8488, 0.1013), Test: (0.8435, 0.0842)
# 2 Train: (0.8490, 0.1003), Test: (0.8435, 0.0814)
# 3 Train: (0.8489, 0.0995), Test: (0.8431, 0.0820)
# 4 Train: (0.8493, 0.1010), Test: (0.8428, 0.0835)
# 5 Train: (0.8496, 0.1014), Test: (0.8431, 0.0841)
# 6 Train: (0.8499, 0.1026), Test: (0.8433, 0.0847)
# 7 Train: (0.8498, 0.1036), Test: (0.8433, 0.0857)
# 8 Train: (0.8498, 0.1039), Test: (0.8428, 0.0869)
# 9 Train: (0.8500, 0.1033), Test: (0.8427, 0.0860)
# 10 Train: (0.8502, 0.1025), Test: (0.8427, 0.0844)
# 11 Train: (0.8501, 0.1042), Test: (0.8427, 0.0847)
# 12 Train: (0.8506, 0.1045), Test: (0.8428, 0.0844)
# 13 Train: (0.8506, 0.1055), Test: (0.8429, 0.0856)
# 14 Train: (0.8508, 0.1054), Test: (0.8429, 0.0838)
# 15 Train: (0.8510, 0.1068), Test: (0.8432, 0.0847)
# 16 Train: (0.8513, 0.1065), Test: (0.8428, 0.0838)
# 17 Train: (0.8516, 0.1051), Test: (0.8430, 0.0822)
# 18 Train: (0.8514, 0.1067), Test: (0.8428, 0.0819)
# ...

# %%
draw(res)

# %%
res=flip('adult','sex',n_epoch=1000,kind='EO',ascending=False)
# Out:
# 0 Train: (0.8485, 0.1012), Test: (0.8430, 0.0876)
# 1 Train: (0.8476, 0.1076), Test: (0.8408, 0.0905)
# 2 Train: (0.8458, 0.1073), Test: (0.8386, 0.0937)
# 3 Train: (0.8440, 0.1154), Test: (0.8361, 0.1077)
# 4 Train: (0.8420, 0.1118), Test: (0.8343, 0.1097)
# 5 Train: (0.8417, 0.1109), Test: (0.8344, 0.1109)
# 6 Train: (0.8409, 0.1097), Test: (0.8339, 0.1142)
# 7 Train: (0.8404, 0.1078), Test: (0.8338, 0.1133)
# 8 Train: (0.8389, 0.1130), Test: (0.8327, 0.1108)
# 9 Train: (0.8386, 0.1120), Test: (0.8323, 0.1110)
# 10 Train: (0.8381, 0.1112), Test: (0.8317, 0.1085)
# 11 Train: (0.8377, 0.1096), Test: (0.8319, 0.1131)
# 12 Train: (0.8369, 0.1053), Test: (0.8318, 0.1103)
# 13 Train: (0.8366, 0.1054), Test: (0.8317, 0.1109)
# 14 Train: (0.8355, 0.1026), Test: (0.8315, 0.1084)
# 15 Train: (0.8351, 0.1009), Test: (0.8316, 0.1078)
# 16 Train: (0.8348, 0.0993), Test: (0.8317, 0.1062)
# 17 Train: (0.8343, 0.0959), Test: (0.8317, 0.1046)
# 18 Train: (0.8337, 0.0939), Test: (0.8319, 0.1065)
# ...

# %%
draw(res)

# %%
res=flip('compas','race',n_epoch=1000,kind='EO',ascending=True)
# Out:
# 0 Train: (0.7202, 0.0200), Test: (0.7198, 0.0514)
# 1 Train: (0.7207, 0.0172), Test: (0.7197, 0.0525)
# 2 Train: (0.7212, 0.0159), Test: (0.7197, 0.0525)
# 3 Train: (0.7213, 0.0135), Test: (0.7197, 0.0525)
# 4 Train: (0.7213, 0.0112), Test: (0.7198, 0.0525)
# 5 Train: (0.7215, 0.0088), Test: (0.7197, 0.0525)

# %%
draw(res)

# %%
res=flip('compas','race',n_epoch=1000,kind='EO',ascending=False)
# Out:
# 0 Train: (0.7202, 0.0200), Test: (0.7198, 0.0514)
# 1 Train: (0.7202, 0.0149), Test: (0.7209, 0.0433)
# 2 Train: (0.7195, 0.0123), Test: (0.7205, 0.0433)
# 3 Train: (0.7188, 0.0122), Test: (0.7203, 0.0449)
# 4 Train: (0.7178, 0.0098), Test: (0.7198, 0.0449)

# %%
draw(res)

# %%
res=flip('compas','sex',n_epoch=1000,kind='EO',ascending=True)
# Out:
# 0 Train: (0.7216, 0.0139), Test: (0.7182, 0.0182)
# 1 Train: (0.7219, 0.0120), Test: (0.7186, 0.0185)
# 2 Train: (0.7219, 0.0109), Test: (0.7182, 0.0161)
# 3 Train: (0.7222, 0.0061), Test: (0.7132, 0.0123)

# %%
draw(res)

# %%
res=flip('compas','sex',n_epoch=1000,kind='EO',ascending=False)
# Out:
# 0 Train: (0.7216, 0.0139), Test: (0.7182, 0.0182)
# 1 Train: (0.7209, 0.0130), Test: (0.7183, 0.0170)
# 2 Train: (0.7201, 0.0051), Test: (0.7138, 0.0115)

# %%
draw(res)
